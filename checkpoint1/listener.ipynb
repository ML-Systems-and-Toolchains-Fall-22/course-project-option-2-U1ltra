# %% [markdown]
# This file implements the tweeter listener, which act as the kafka producer and post the stream for consumer to process.

# %%
import tweepy
import time
from kafka import KafkaProducer

bearer_token= r"AAAAAAAAAAAAAAAAAAAAACddhQEAAAAAJf6G0ZqwhPI46bXY7WvUjtlmio4%3DqYBBgJ3mkE49mJj0WNvrfbXCg7lbiPldBelynrrQkCEYrlyKTH"
api_key = "sIZmnRFGSXlruVfOWFOev6eGX"
api_secret = "6HggNXL2llVLVxNzXEpqMwLXAfu2uLoLoO2JWzk7RWHHykwlED"
access_token = '1571982292217733121-FpSCelJc2NeTaYnqiV7TxlnHNUahv8'
access_token_secret = 'XNqPSbfxfjPMKpF34789QpLutjvfIkrtjWWf0PDxrEgvX'

tweepy.Client(bearer_token,api_key,api_secret,access_token,access_token_secret)
auth = tweepy.OAuth1UserHandler(api_key,api_secret,access_token,access_token_secret)
api = tweepy.API(auth)

topic_name = "mqtt_attack"
topic_name = "testing"
search_terms = ["IoT-attack", "IoT-crime"]
search_terms = [
    "slowite",
    "bruteforce",
    "flood",
    "malformed",
    "dos"
]
producer = KafkaProducer(bootstrap_servers='localhost:9092')


class MyStream(tweepy.StreamingClient):

    def on_status(self, status):
        print(status.text)
        
    def on_connect(self):
        print("connected")
    
    def on_tweet(self,tweet):
        if tweet.referenced_tweets == None:
            print (tweet.text)
            producer.send(topic_name,tweet.text.encode('utf-8'))
            time.sleep(1.5)
            
            
stream = MyStream(bearer_token=bearer_token)

for term in search_terms:
    stream.add_rules(tweepy.StreamRule(term))   # filter rule - search term

stream.filter(tweet_fields=["referenced_tweets"])
# Out:
# connected
# les gens qui parlent dans le dos de leurs copines cv pass???
# Asafa Powell, ex-recordista mundial dos 100 metros, oficializa retirada das pistas https://t.co/fc00zJ7vgr https://t.co/DIKXhbFLUH
# É A VELHA HIPOCRISIA DOS PETISTAS ESPALHANDO O ÓDIO! TENHAM CUIDADO, POIS QUEM PLANTA VENTO, COLHE TEMPESTADE.
# Publicar um novo Tweet / Twitter https://t.co/IP3Og7Uj5k
# UNLOCK SERVICES
#
# ✨Bartleby / Chegg ₱2✨
# —Textbook ₱5
# —Unli Unlocks ₱30/30 mins
#
# ✨Coursehero ₱10
# ✨Numerade ₱15
#
# ✨Scribd ₱8
# ✨Studocu ₱8
#
# ✨Chegg/Bartleby Account ₱150✨
# —Unli Unlocks
# —Any Device
# Numerade / Scribd / Studocu Account
#
# lf 1 two dos Piso ph rush
# 🫰149
# Menos d dos minutos y Canadá ya metió un gol, Canadá mi candidato para q gane el mundial YIAA LDBEKD
# Essa copa é inimiga dos bolões 😂
# a cual de mis dos festivales irían?? https://t.co/Xu1EgB7wvQ
# e sobre o Jonghan que abriu o show, que pessoa adorável
# QUE VOZ EM CARAA!!!!
# já ganhou o coração dos ahgases ali mesmo 💚
# no hay término medio en tuiter:o el halago desmesurado  o el insulto gratuito
# tanto monta monta tanto
# ninguna de las dos cosas hacen un mundo mejor
# Dos vicepresidentes de YPF fueron imputados por la persecusión al Grupo Indalo https://t.co/YWIpdPq5KJ
# Cólica dos inferno
# A Canadá no se le abrió el arco ante Bélgica, pero en menos de dos minutos ya pudo ante Croacia.
# Mnnn, Thayna vem me contar as coisas e ela não me poupa dos detalhes não kkkkkkkkkkk
# eu no auge dos 29 anos
# Imagina o gajo que aposta 1 Gol antes dos 5min.. fogo
# Que golaço do Canadá, primeiro gol em mundiais e tinha que vir dos pés de Aphonso Davies 👏👏
# time do canadá o terror dos velhos. time mais bem preparado fisiamente desde o brasil de 70
# a química dos dois deu certo pq os dois são casados na vida real e isso fez diferença
# #Qatar2022 Croacia 0 - 1 Canadá
#
# ⚽️ Alphonso Davis abre el marcador apenas en dos minutos de partido.
#
# #HablaDeportesEsMundial https://t.co/6TySL5hRZh
# UNLOCK SERVICES
#
# ✨Bartleby / Chegg ₱2✨
# —Textbook ₱5
# —Unli Unlocks ₱30/30 mins
#
# ✨Coursehero ₱10
# ✨Numerade ₱15
#
# ✨Scribd ₱8
# ✨Studocu ₱8
#
# ✨Chegg/Bartleby Account ₱150✨
# —Unli Unlocks
# —Any Device
# Numerade / Scribd / Studocu Account
#
# lf 1 two dos Piso ph rush
# 🫰150
# As a furry nsfw artist I can agree that irl I'm entirely against the disgusting irl zoos and p*dos on this website!
#
# I have standards https://t.co/bvfXDNSzcp
# Muito bom ver a comemoração dos canadenses no primeiro gol deles na história das copa. #Can #WorldcupQatar2022
# Gov golpista e a Corrupção na Saúde: Saco de dinheiro do SUS - Hospital Ouro Verde.
# Corrupção na Educação: Operação Cadeia Alimentar I (2018) e Cadeia Alimentar II (2019) da PF c/desvios Merenda Escolar.
# Condenação TJ de SP: Trem da Alegria dos Comissionados com altos salários. https://t.co/Pw5D6RzIEn
# UNLOCK SERVICES
#
# ✨Bartleby / Chegg ₱2✨
# —Textbook ₱5
# —Unli Unlocks ₱30/30 mins
#
# ✨Coursehero ₱10
# ✨Numerade ₱15
#
# ✨Scribd ₱8
# ✨Studocu ₱8
#
# ✨Chegg/Bartleby Account ₱150✨
# —Unli Unlocks
# —Any Device
# Numerade / Scribd / Studocu Account
#
# lf 1 two dos Piso ph rush
# 🫰151
# Uma outra coisa que tenho comigo é: eu realmente tenho zero apego com qualquer um dos jogadores do elenco atual. Mas todo movimento ou decisão tomada precisa ser visando o time, não um jogador específico. Adianta nada potencializar só um jogador e o time ficar sem versatilidade+
# você vê que as críticas passaram dos limites quando o neto tá defendendo o Neymar
# La TRE (Tasa de Retorno Energético) se confunde muchas veces con el EPBT (tiempo de retorno energético). ¿Qué diferencias hay entre estos dos conceptos? ¿Acaso una FV recupera su energía invertida muy lentamente? Te lo explico en mi nuevo artículo.
# https://t.co/Jm3nucu6BS https://t.co/YLhVwetbSy
# Os asiáticos atualmente tem feito bastante conteúdo de qualidade, além dos animes que sempre foram bons. Eu mesmo prefiro consumir o que eles produzem!
# Pero ARMY ellos solo bailaron que ptas les pasa? Jajajaja en fin stream a Dreamers e  yt que está dos en tendencia omg omg
# Se la tire dos veces y se hizo bien la boludita, igual ni quería.
# Divulguem para 30! Se trinta divulgarem para mais 30, serão 900! Se os novecentos divulgarem para mais 30, serão 27.000! E se esses, divulgarem para mais 30, serão 810.000!
# É fácil entender o medo dos Tribunais e da esquerda. É tão rápido, tanto quanto a velocidade da luz! ✨ https://t.co/TBrsgIyrUR
# Nunca había sentido tan latente la sensación de tener sólo dos opciones para sentirme libre, o me muero o me voy de mi casa. No hay de otra
# O Oregon pode ser duro as vezes....
#
# Defesa impenetrável dos franceses, como que passa?
#
# Liquid (1) 0 x 4 (1) BDS
#
# #SixMajor
# 🎶solo recuerda que no cabe el odio entre dos pirobos que un día fueron novios 🎶
# Estar rodeados de personas, que pase algo que solo los dos entendemos y llorar de risa con el Andrés es todo lo que está bien.❤️
# En Argentina es netamente imposible poder comprarte un departamento teniendo solo un trabajo. O trabajas en dos lugares a la vez o aumentas la carga horaria, en ambas opciones terminas siendo un esclavo estatal que paga impuestos para qje a los diputados les aumenten a $500.000
# The transit was damaged by flood https://t.co/vsQz7Iszoz
# Cm assim Larissa Manoela, Malu Galli e Giovanna Antonelli foram subestimadas dos Melhores do Ano por esse elenco de Pantanal??
# NN ACEITO JAMAIS! https://t.co/hlIQ9P6W8X
# Olá, gentamiga,
# Cecilia Meirelles, Camus, a escuridão de Händel, Rita Lino &amp; muito mais nas dicas de artes dos mais de 5 milhões de acessos ao TTTTT: https://t.co/nPgPhYW1WD
# #tataritaritata #livroterapia https://t.co/i9iSc6i6Bu
# Ever since Elon took over, it's like the flood gates have been opened. Twitter is fun once again.
# Canadá dando el batacazo en los dos primeros minutos
# #CRO 0-1 #CAN
# #Qatar2022
# #FIFAWorldCup
# Yo digo que quiero salir y a las dos horas me arrepiento
# tô fugindo de colocar biquíni igual fujo dos meus problemas
# Tengo que aprender a dejar de regalar mi trabajo... El que no lo valore dos besitos.
# Sempre 10 anos a frente dos otário 😅
# Esse grupo da Bélgica e da Croácia tá um dos mais divertidos da Copa todo mundo
# Y con este gol México en automático se convierte en el único equipo de CONCACAF que no ha anotado luego de dos partidos jugados
# É uma merda sentir que tudo que faço tá errado, mas ficar esperando iniciativa dos outros me cansa demais
# a química dos dois deu certo pq os dois são casados na vida real e isso fez diferença nas cenas de amorzinho
# O Canadá merecia ter ganhado dos velhotes da bélgica
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 48
#      45 for term in search_terms:
#      46     stream.add_rules(tweepy.StreamRule(term))   # filter rule - search term
# ---> 48 stream.filter(tweet_fields=["referenced_tweets"])
#
# File /usr/local/lib/python3.10/site-packages/tweepy/streaming.py:791, in StreamingClient.filter(self, threaded, **params)
#     789     return self._threaded_connect(method, endpoint, params=params)
#     790 else:
# --> 791     self._connect(method, endpoint, params=params)
#
# File /usr/local/lib/python3.10/site-packages/tweepy/streaming.py:611, in StreamingClient._connect(self, method, endpoint, **kwargs)
#     609 self.session.headers["Authorization"] = f"Bearer {self.bearer_token}"
#     610 url = f"https://api.twitter.com/2/tweets/{endpoint}/stream"
# --> 611 super()._connect(method, url, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/tweepy/streaming.py:91, in BaseStream._connect(self, method, url, auth, params, headers, body)
#      87 for line in resp.iter_lines(
#      88     chunk_size=self.chunk_size
#      89 ):
#      90     if line:
# ---> 91         self.on_data(line)
#      92     else:
#      93         self.on_keep_alive()
#
# File /usr/local/lib/python3.10/site-packages/tweepy/streaming.py:921, in StreamingClient.on_data(self, raw_data)
#     919 if "data" in data:
#     920     tweet = Tweet(data["data"])
# --> 921     self.on_tweet(tweet)
#     922 if "includes" in data:
#     923     includes = self._process_includes(data["includes"])
#
# Cell In [1], line 40, in MyStream.on_tweet(self, tweet)
#      38 print (tweet.text)
#      39 producer.send(topic_name,tweet.text.encode('utf-8'))
# ---> 40 time.sleep(1.5)
#
# KeyboardInterrupt:
